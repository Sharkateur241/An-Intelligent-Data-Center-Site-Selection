# %% [markdown]
# # Data Center Site Selection Analysis Example
#
# This notebook demonstrates how to perform location analysis using a data center intelligent site selection system.

# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
